# %%
#import pandas as pd
import xarray as xr

# %%
ds = xr.open_dataset('_grib2netcdf-atls00-95e2cf679cd58ee9b4db4dd119a05a8d-UIcz7w.nc')

# %%
ds.to_dataframe()
# Out:
#                                               u10
# latitude longitude time
#  90.0    0.00      2015-12-01 18:00:00  -3.790418
#                    2015-12-02 18:00:00  -7.474918
#                    2015-12-03 18:00:00 -13.199034
#                    2015-12-04 18:00:00  -9.979039
#                    2015-12-05 18:00:00  -6.977916
#                    2015-12-06 18:00:00  -4.258746
#                    2015-12-07 18:00:00  -2.467630
#                    2015-12-08 18:00:00  -5.378911
#                    2015-12-09 18:00:00  -5.665642
#                    2015-12-10 18:00:00  -4.545478
#                    2015-12-11 18:00:00  -3.779905
#                    2015-12-12 18:00:00  -7.000855
#                    2015-12-13 18:00:00  -7.577185
#                    2015-12-14 18:00:00  -0.203407
#                    2015-12-15 18:00:00   2.985047
#                    2015-12-16 18:00:00   4.057423
#                    2015-12-17 18:00:00   3.378825
# ...
